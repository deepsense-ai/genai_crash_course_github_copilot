# %% [markdown]
# # Exercise 1 - Jupyter Notebooks + Autocomplete
#
# The Jupyter Notebooks inside VS Code work seamlesly with all GH Copilot features. Let's see few of them.
#
# ## Autocomplete in Jupyter cells
#
# You can type and Copilot will start to sugest next changes. It can also implement based on comments, function names etc.
#
# > **Task**
# >
# > Implement a load_california_housing_df() that loads Scikit Learn California housing dataset as Pandas dataframe.

# %%
# Validation logic

df =  load_california_housing_df()
assert df.shape == (20640, 9), "DataFrame shape is not as expected"
